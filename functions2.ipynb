# %%
def expenses_made():
  expenses=[]
  number_of_days=int(input("enter the number of days"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))
    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses

total_expenditure=expenses_made()
print("daily expenses")
for expenditure in total_expenditure:
  print(expenditure[0],"expenses are",expenditure[1])

# %%
def expenses_made():
  expenses=[]
  number_of_days=int(input("enter the number of days"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))
    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses
total_expenditure=expenses_made()
print("daily expenses")
for expenditure in total_expenditure:
  print(expenditure[0],"expenses are",expenditure[1])
for day in total_expenditure:
  print(day[0],"total:",sum(day[1]))
day1_total=sum(total_expenditure[0][1])
day2_total=sum(total_expenditure[1][1])
sum1=day1_total+day2_total
print("overall expenses:",sum1)
# Out:
# enter the number of days2
# enter the day nameday1
# enter the seed cost:100
# enter the fertilizer cost:200
# enter the labour cost:300
# enter the day nameday2
# enter the seed cost:200
# enter the fertilizer cost:100
# enter the labour cost:399
# daily expenses
# day1 expenses are [100, 200, 300]
# day2 expenses are [200, 100, 399]
# day1 total: 600
# day2 total: 699
# overall expenses: 1299

# %%
farm_data=[
      [1,"rice",45],
      [2,"wheat",30],
      [3,"maize",60]
]
print(farm_data)
print(farm_data[0])
print(farm_data[1][2])
# Out:
# [[1, 'rice', 45], [2, 'wheat', 30], [3, 'maize', 60]]
# [1, 'rice', 45]
# 30

# %%
def expenses_made():
  expenses=[]
  number_of_days=int(input("enter the number of days"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))
    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses
total_expenditure=expenses_made()
print("daily expenses")
for expenditure in total_expenditure:
  print(expenditure[0],"expenses are",expenditure[1])
for day in total_expenditure:
  print(day[0],"total:",sum(day[1]))
day1_total=sum(total_expenditure[0][1])
day2_total=sum(total_expenditure[1][1])
sum1=day1_total+day2_total
print("overall expenses:",sum1)

def crop_record():
  crop_record()
  crop_name=input("enter the crop name:")
  season_of_cultivation=input("Enter the season(rabi/kharif/zaid)")
  expected_yield=int(input("Enter the expected yield(kg per hectare):"))
  crop_record.append((crop_name,(season_of_cultivation,expected_yield)))
  return crop_record

# %%
def expenses_made():
  expenses=[]
  number_of_days=int(input("enter the number of days"))
  for i in range(number_of_days):
    day_name=input(f"enter the day name")
    seed_cost=int(input("enter the seed cost:"))
    fertilizer_cost=int(input("enter the fertilizer cost:"))
    labour_cost=int(input("enter the labour cost:"))
    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses
total_expenditure=expenses_made()
print("daily expenses")
for expenditure in total_expenditure:
  print(expenditure[0],"expenses are",expenditure[1])
for day in total_expenditure:
  print(day[0],"total:",sum(day[1]))
day1_total=sum(total_expenditure[0][1])
day2_total=sum(total_expenditure[1][1])
sum1=day1_total+day2_total
print("overall expenses:",sum1)

def crop_record():
  crop_record()
  crop_name=input("enter the crop name:")
  season_of_cultivation=input("Enter the season(rabi/kharif/zaid)")
  expected_yield=int(input("Enter the expected yield(kg per hectare):"))
  crop_record.append((crop_name,(season_of_cultivation,expected_yield)))
  return crop_record
