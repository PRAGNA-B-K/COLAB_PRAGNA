# %%
#creating string
crop="rice"
soil_type="black soil"
print(crop)
print(soil_type)
# Out:
# rice
# black soil

# %%
crop="rice"
soil_type="black soil"
print(crop)
print(soil_type)
print(len(crop))
# Out:
# rice
# black soil
# 4

# %%
#indexing and slicing
crop_name="groundnut"
print(crop_name[0])
print(crop_name[-4])
print(crop_name[4:])
print(crop_name[:6])
# Out:
# g
# d
# ndnut
# ground

# %%
print("ragi".upper())
print("WHEAT".lower())
print("green gram".title())
print("cotton candy".capitalize())
# Out:
# RAGI
# wheat
# Green Gram
# Cotton candy

# %%
#trimming
raw_crop="    rice    "
print(raw_crop.strip())
print("***wheat".lstrip("*"))
print("cotton###".rstrip("#"))
print("sesame###".strip("#"))
print("    niger###".strip().rstrip("#"))
print("    sunflower###".strip().strip("#"))
# Out:
# rice
# wheat
# cotton
# sesame
# niger
# sunflower

# %%
#searching
text="Organic Rice and Rice cultivation"
print(text.find("Rice"))
print(text.count("Rice"))
print("Rice" in text)
print("Rice".isalpha())
print("2026".isdigit())
print("plot29".isalnum())
print("  ".isspace())
# Out:
# 8
# 2
# True
# True
# True
# True
# True

# %%
codes=[
    "CRP_RICE_2026",
    "CRP_WHEAT_2025",
    "FRT_GRAPES_2024",
    "CRP_RAGI_2026"
]
clean_code=[]
for code in codes:
  if code.startswith("CRP_"):
   clean_code.append(code[4:])
print(clean_code)
# Out:
# ['RICE_2026', 'WHEAT_2025', 'RAGI_2026']

# %%
codes=[
    "CRP_RICE_2026",
    "CRP_WHEAT_2025",
    "FRT_GRAPES_2024",
    "CRP_RAGI_2026"
]
for crop_codes in codes:
  if crop_codes.startswith("CRP_"):
    code,crop,year=crop_codes.split("_")
    print(crop,year)
# Out:
# RICE 2026
# WHEAT 2025
# RAGI 2026

# %%
raw_record="    rice,1200,black soil***"
clean_record=raw_record.strip("*").strip()
crop,yield_kg,soil=clean_record.split(",")
crop=crop.title()
soil=soil.title()
print(f"crop:{crop}")
print(f"yield:{yield_kg},kg")
print(f"soil:{soil}")
# Out:
# crop:Rice
# yield:1200,kg
# soil:Black Soil
