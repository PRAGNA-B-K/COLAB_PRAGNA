# %%
import pandas as pd
import numpy as np
#create sample data frame
df=pd.DataFrame({
    "name":["alice","bob","charlie","david","eva","frank"],
    "department":["HR","IT","IT","FINANCE","HR","FINANCE"],
    "salary":[50000,70000,70000,60000,52000,60000],
    "experience":[2,5,4,6,3,6]
})
print(df)
# Out:
#       name department  salary  experience
# 0    alice         HR   50000           2
# 1      bob         IT   70000           5
# 2  charlie         IT   70000           4
# 3    david    FINANCE   60000           6
# 4      eva         HR   52000           3
# 5    frank    FINANCE   60000           6

# %%
df['dence_rank_salary']=df['salary'].rank(ascending=False,method='dense')
print(df)
# Out:
#       name department  salary  experience  dence_rank_salary
# 0    alice         HR   50000           2                4.0
# 1      bob         IT   70000           5                1.0
# 2  charlie         IT   70000           4                1.0
# 3    david    FINANCE   60000           6                2.0
# 4      eva         HR   52000           3                3.0
# 5    frank    FINANCE   60000           6                2.0

# %%
#sort by one column(ascending)
sal=df.sort_values("salary")
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 0    alice         HR   50000           2                4.0
# 4      eva         HR   52000           3                3.0
# 5    frank    FINANCE   60000           6                2.0
# 3    david    FINANCE   60000           6                2.0
# 2  charlie         IT   70000           4                1.0
# 1      bob         IT   70000           5                1.0

# %%
#sort by one column(descending)
sal=df.sort_values("salary",ascending=False)
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 1      bob         IT   70000           5                1.0
# 2  charlie         IT   70000           4                1.0
# 5    frank    FINANCE   60000           6                2.0
# 3    david    FINANCE   60000           6                2.0
# 4      eva         HR   52000           3                3.0
# 0    alice         HR   50000           2                4.0

# %%
#sort by one column(descending)
sal=df.sort_values("salary",ascending=True)
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 0    alice         HR   50000           2                4.0
# 4      eva         HR   52000           3                3.0
# 5    frank    FINANCE   60000           6                2.0
# 3    david    FINANCE   60000           6                2.0
# 2  charlie         IT   70000           4                1.0
# 1      bob         IT   70000           5                1.0

# %%
#multiple columns
sal=df.sort_values(["salary","experience"],ascending=[False,True])
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 2  charlie         IT   70000           4                1.0
# 1      bob         IT   70000           5                1.0
# 3    david    FINANCE   60000           6                2.0
# 5    frank    FINANCE   60000           6                2.0
# 4      eva         HR   52000           3                3.0
# 0    alice         HR   50000           2                4.0

# %%
#multiple columns
sal=df.sort_values(["salary","experience"],ascending=[False,False])
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 1      bob         IT   70000           5                1.0
# 2  charlie         IT   70000           4                1.0
# 3    david    FINANCE   60000           6                2.0
# 5    frank    FINANCE   60000           6                2.0
# 4      eva         HR   52000           3                3.0
# 0    alice         HR   50000           2                4.0

# %%
#multiple columns
sal=df.sort_values(["salary","experience"],ascending=[True,True])
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 0    alice         HR   50000           2                4.0
# 4      eva         HR   52000           3                3.0
# 3    david    FINANCE   60000           6                2.0
# 5    frank    FINANCE   60000           6                2.0
# 2  charlie         IT   70000           4                1.0
# 1      bob         IT   70000           5                1.0

# %%
#multiple columns
sal=df.sort_values(["salary","experience"],ascending=[True,False])
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 0    alice         HR   50000           2                4.0
# 4      eva         HR   52000           3                3.0
# 3    david    FINANCE   60000           6                2.0
# 5    frank    FINANCE   60000           6                2.0
# 1      bob         IT   70000           5                1.0
# 2  charlie         IT   70000           4                1.0

# %%
#multiple columns
sal=df.sort_values(["name","experience"],ascending=[False,True])
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 5    frank    FINANCE   60000           6                2.0
# 4      eva         HR   52000           3                3.0
# 3    david    FINANCE   60000           6                2.0
# 2  charlie         IT   70000           4                1.0
# 1      bob         IT   70000           5                1.0
# 0    alice         HR   50000           2                4.0

# %%
#multiple columns
sal=df.sort_values(["name","experience"],ascending=[True,True])
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 0    alice         HR   50000           2                4.0
# 1      bob         IT   70000           5                1.0
# 2  charlie         IT   70000           4                1.0
# 3    david    FINANCE   60000           6                2.0
# 4      eva         HR   52000           3                3.0
# 5    frank    FINANCE   60000           6                2.0

# %%
#multiple columns
sal=df.sort_values(["name","experience"],ascending=[False,False])
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 5    frank    FINANCE   60000           6                2.0
# 4      eva         HR   52000           3                3.0
# 3    david    FINANCE   60000           6                2.0
# 2  charlie         IT   70000           4                1.0
# 1      bob         IT   70000           5                1.0
# 0    alice         HR   50000           2                4.0

# %%
#multiple columns
sal=df.sort_values(["name","department"],ascending=[False,False])
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 5    frank    FINANCE   60000           6                2.0
# 4      eva         HR   52000           3                3.0
# 3    david    FINANCE   60000           6                2.0
# 2  charlie         IT   70000           4                1.0
# 1      bob         IT   70000           5                1.0
# 0    alice         HR   50000           2                4.0

# %%
#multiple columns
sal=df.sort_values(["department","name"],ascending=[False,False])
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 2  charlie         IT   70000           4                1.0
# 1      bob         IT   70000           5                1.0
# 4      eva         HR   52000           3                3.0
# 0    alice         HR   50000           2                4.0
# 5    frank    FINANCE   60000           6                2.0
# 3    david    FINANCE   60000           6                2.0

# %%
#multiple columns
sal=df.sort_values(["salary","experience"],ascending=[True,True])
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 0    alice         HR   50000           2                4.0
# 4      eva         HR   52000           3                3.0
# 3    david    FINANCE   60000           6                2.0
# 5    frank    FINANCE   60000           6                2.0
# 2  charlie         IT   70000           4                1.0
# 1      bob         IT   70000           5                1.0

# %%
sal=df.sort_values(["salary","experience"])
print(sal)
# Out:
#       name department  salary  experience  dence_rank_salary
# 0    alice         HR   50000           2                4.0
# 4      eva         HR   52000           3                3.0
# 3    david    FINANCE   60000           6                2.0
# 5    frank    FINANCE   60000           6                2.0
# 2  charlie         IT   70000           4                1.0
# 1      bob         IT   70000           5                1.0

# %%
des=df.sort_index(ascending=False)
print(des)
# Out:
#       name department  salary  experience  dence_rank_salary
# 5    frank    FINANCE   60000           6                2.0
# 4      eva         HR   52000           3                3.0
# 3    david    FINANCE   60000           6                2.0
# 2  charlie         IT   70000           4                1.0
# 1      bob         IT   70000           5                1.0
# 0    alice         HR   50000           2                4.0

# %%
#indexing
import pandas as pd
import numpy as numpy
#create sample data frame
data={
    "name":["alice","bob","charlie","david","eva","frank"],
    "department":["HR","IT","IT","FINANCE","HR","FINANCE"],
    "salary":[50000,70000,70000,60000,52000,60000],
    "experience":[2,5,4,6,3,6]
}
df=pd.DataFrame(data,index=["employee1","employee2","employee3","employee4","employee5","employee6"])
print(df)
# Out:
#               name department  salary  experience
# employee1    alice         HR   50000           2
# employee2      bob         IT   70000           5
# employee3  charlie         IT   70000           4
# employee4    david    FINANCE   60000           6
# employee5      eva         HR   52000           3
# employee6    frank    FINANCE   60000           6

# %%
#ranking examples
#basic ranking (default ascending)
df['rank_salary']=df['salary'].rank()
print(df)
# Out:
#               name department  salary  experience  rank_salary
# employee1    alice         HR   50000           2          1.0
# employee2      bob         IT   70000           5          5.5
# employee3  charlie         IT   70000           4          5.5
# employee4    david    FINANCE   60000           6          3.5
# employee5      eva         HR   52000           3          2.0
# employee6    frank    FINANCE   60000           6          3.5

# %%
df['rank_salary']=df['salary'].rank(ascending=True)
print(df)
# Out:
#               name department  salary  experience  rank_salary
# employee1    alice         HR   50000           2          1.0
# employee2      bob         IT   70000           5          5.5
# employee3  charlie         IT   70000           4          5.5
# employee4    david    FINANCE   60000           6          3.5
# employee5      eva         HR   52000           3          2.0
# employee6    frank    FINANCE   60000           6          3.5

# %%
df['rank_salary']=df['salary'].rank(ascending=False)
print(df)
# Out:
#               name department  salary  experience  rank_salary
# employee1    alice         HR   50000           2          6.0
# employee2      bob         IT   70000           5          1.5
# employee3  charlie         IT   70000           4          1.5
# employee4    david    FINANCE   60000           6          3.5
# employee5      eva         HR   52000           3          5.0
# employee6    frank    FINANCE   60000           6          3.5

# %%
df['dence_rank_salary']=df['salary'].rank(ascending=False,method='dense')
print(df)
# Out:
#               name department  salary  experience  rank_salary  \
# employee1    alice         HR   50000           2          6.0
# employee2      bob         IT   70000           5          1.5
# employee3  charlie         IT   70000           4          1.5
# employee4    david    FINANCE   60000           6          3.5
# employee5      eva         HR   52000           3          5.0
# employee6    frank    FINANCE   60000           6          3.5
#
#            dence_rank_salary
# employee1                4.0
# employee2                1.0
# employee3                1.0
# employee4                2.0
# employee5                3.0
# employee6                2.0

# %%
df['dence_rank_salary']=df['salary'].rank(ascending=False)
print(df)
# Out:
#               name department  salary  experience  rank_salary  \
# employee1    alice         HR   50000           2          6.0
# employee2      bob         IT   70000           5          1.5
# employee3  charlie         IT   70000           4          1.5
# employee4    david    FINANCE   60000           6          3.5
# employee5      eva         HR   52000           3          5.0
# employee6    frank    FINANCE   60000           6          3.5
#
#            dence_rank_salary
# employee1                6.0
# employee2                1.5
# employee3                1.5
# employee4                3.5
# employee5                5.0
# employee6                3.5

# %%
df=df['department'].value_counts()
print(df)
# Out:
# department
# HR         2
# IT         2
# FINANCE    2
# Name: count, dtype: int64

# %%
sdf=df['department'].value_counts(normalize=True)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'department'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1616725577.py in <cell line: 0>()
# ----> 1 df=df['department'].value_counts(normalize=True)
# ...

# %%
df=pd.DataFrame({
    "name":["alice","bob","charlie","david","eva","frank"],
    "department":["HR","IT","IT","FINANCE","HR","FINANCE"],
    "salary":[50000,70000,70000,60000,52000,60000],
    "experience":[2,5,4,6,3,6]
})
prop=df['department'].value_counts(normalize=True)
print(prop)
# Out:
# department
# HR         0.333333
# IT         0.333333
# FINANCE    0.333333
# Name: proportion, dtype: float64

# %%
df=pd.DataFrame({
    "name":["alice","bob","charlie","david","eva","frank"],
    "department":["HR","IT","IT","FINANCE","HR","FINANCE"],
    "salary":[50000,70000,70000,60000,52000,60000],
    "experience":[2,5,4,6,3,6]
})
prop=df['department'].value_counts(normalize=False)
print(prop)
# Out:
# department
# HR         2
# IT         2
# FINANCE    2
# Name: count, dtype: int64

# %%
#basic plotting example
#line plot
import matplotlib.pyplot as plt
df[['salary','experience']].plot()
plt.show()

# %%
#bar chart
df.plot(kind='bar',x='name',y='salary')
plt.show()

# %%
df.plot(kind='pie',x='name',y='salary')
plt.show()

# %%
df.plot(kind='pie',x='experience',y='salary')
plt.show()

# %%
df.plot(kind='pie',x='salary',y='experience')
plt.show()

# %%
df['salary'].plot(kind='hist',bins=5)
plt.show()

# %%
df=pd.DataFrame({
    "name":["alice","bob","charlie","david","eva","frank","george"],
    "department":["HR","IT","IT","FINANCE","HR","FINANCE","CEO"],
    "salary":[50000,70000,70000,60000,52000,60000,90000],
    "experience":[2,5,4,6,3,6,7]
})
df['salary'].plot(kind='hist',bins=10)
plt.show()

# %%
#scatter plot
df.plot(kind='scatter',x='experience',y='salary')
plt.show()

# %%
df.plot(kind='scatter',x='name',y='salary')
plt.show()

# %%
df.plot(kind='scatter',x='salary',y='name')
plt.show()

# %%
#box plot
df[['salary','experience']].plot(kind='box')
plt.show()

# %%
df[['name','experience']].plot(kind='box')
plt.show()

# %%
import pandas as pd
import numpy as numpy
#create sample data frame
df=pd.DataFrame({
    "name":["alice","bob","charlie","david","eva","frank"],
    "department":["HR","IT","IT","FINANCE","HR","FINANCE"],
    "salary":[50000,70000,70000,60000,52000,60000],
    "experience":[2,5,4,6,3,6]
})
print(df)
# Out:
#       name department  salary  experience
# 0    alice         HR   50000           2
# 1      bob         IT   70000           5
# 2  charlie         IT   70000           4
# 3    david    FINANCE   60000           6
# 4      eva         HR   52000           3
# 5    frank    FINANCE   60000           6

# %%
df.loc[0]
# Out:
# name          alice
# department       HR
# salary        50000
# experience        2
# Name: 0, dtype: object

# %%
df.loc[0,'name']
# Out:
# 'alice'

# %%
df.loc[:,'name']
# Out:
# 0      alice
# 1        bob
# 2    charlie
# 3      david
# 4        eva
# 5      frank
# Name: name, dtype: object

# %%
df.loc[1:5,['name','department']]
# Out:
#       name department
# 1      bob         IT
# 2  charlie         IT
# 3    david    FINANCE
# 4      eva         HR
# 5    frank    FINANCE

# %%
df.iloc[1]
# Out:
# name            bob
# department       IT
# salary        70000
# experience        5
# Name: 1, dtype: object

# %%
df.iloc[1,2]
# Out:
# np.int64(70000)

# %%
df.iloc[:,0]
# Out:
# 0      alice
# 1        bob
# 2    charlie
# 3      david
# 4        eva
# 5      frank
# Name: name, dtype: object

# %%
df.iloc[0:5,0:3]
# Out:
#       name department  salary
# 0    alice         HR   50000
# 1      bob         IT   70000
# 2  charlie         IT   70000
# 3    david    FINANCE   60000
# 4      eva         HR   52000

# %%
df[df['salary']>50000]
# Out:
#       name department  salary  experience
# 1      bob         IT   70000           5
# 2  charlie         IT   70000           4
# 3    david    FINANCE   60000           6
# 4      eva         HR   52000           3
# 5    frank    FINANCE   60000           6

# %%
df[(df['salary']>60000) & (df['experience']<8)]
# Out:
#       name department  salary  experience
# 1      bob         IT   70000           5
# 2  charlie         IT   70000           4

# %%
df[(df['salary']>50000) | (df['experience']<8)]
# Out:
#       name department  salary  experience
# 0    alice         HR   50000           2
# 1      bob         IT   70000           5
# 2  charlie         IT   70000           4
# 3    david    FINANCE   60000           6
# 4      eva         HR   52000           3
# 5    frank    FINANCE   60000           6

# %%
df[df['name'].isin(['alice','bob'])]
# Out:
#     name department  salary  experience
# 0  alice         HR   50000           2
# 1    bob         IT   70000           5

# %%
df[df['experience'].between(2,6)]
# Out:
#       name department  salary  experience
# 0    alice         HR   50000           2
# 1      bob         IT   70000           5
# 2  charlie         IT   70000           4
# 3    david    FINANCE   60000           6
# 4      eva         HR   52000           3
# 5    frank    FINANCE   60000           6

# %%
df[df['name'].between('a','d')]
# Out:
#       name department  salary  experience
# 0    alice         HR   50000           2
# 1      bob         IT   70000           5
# 2  charlie         IT   70000           4

# %%
#QUERY METHOD
df.query('experience > 2')
# Out:
#       name department  salary  experience
# 1      bob         IT   70000           5
# 2  charlie         IT   70000           4
# 3    david    FINANCE   60000           6
# 4      eva         HR   52000           3
# 5    frank    FINANCE   60000           6

# %%
df.query('name > A & salary < 80000' )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     230             if self.has_resolvers:
# --> 231                 return self.resolvers[key]
#     232
#
# /usr/lib/python3.12/collections/__init__.py in __getitem__(self, key)
#    1014                 pass
# -> 1015         return self.__missing__(key)            # support subclasses that define __missing__
#    1016
#
# /usr/lib/python3.12/collections/__init__.py in __missing__(self, key)
#    1006     def __missing__(self, key):
# -> 1007         raise KeyError(key)
#    1008
#
# KeyError: 'A'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.query('experience > 2 & salary < 80000' )
# Out:
#       name department  salary  experience
# 1      bob         IT   70000           5
# 2  charlie         IT   70000           4
# 3    david    FINANCE   60000           6
# 4      eva         HR   52000           3
# 5    frank    FINANCE   60000           6

# %%
import pandas as pd
data={
    'farm_id':['F001','F002','F003','F004','F005','F006','F007'],
    'crop':['wheat','rice','corn','wheat','rice','corn','wheat'],
    'yield_tons':[180,228,416,164,245,390,195],
    'rainfall_mm':[450,820,680,420,850,710,480],
    'fertilizer_kg':[120,150,200,110,160,195,125],
    'soil_pH':[6.5,5.8,6.2,6.7,5.9,6.1,6.4]
}
df=pd.DataFrame(data)
df['yield_per_ha']=(df['yield_tons']/50).round(1)
print('original dataset:')
print(df)

#filter 1:high yield farms
print('\n===HIGH YIELD FARMS(>200 tons)===')
high_yield=df[df['yield_tons']>200]
print(high_yield)

#filter 2:multiple conditions (rice with high rainfall)
print('\n===RICE WITH HIGH RAINFALL(>800mm)===')
rice_high_rain=df[(df['crop']=='rice')&(df['rainfall_mm']>800)]
print(rice_high_rain)

#filter 3:using isin for specific crops
print('\n===GRAIN CROPS(wheat&rice)===')
grain_crops=df[df['crop'].isin(['wheat','rice'])]
print(grain_crops[['farm_id','crop','yield_tons']])

#filter 4: range filtering
print('\n===OPTIMAL SOIL pH(6.0 to 6.5)===')
optimal_ph=df[df['soil_pH'].between(6.0,6.5)]
print(optimal_ph[['farm_id','crop','soil_pH','yield_tons']])

#filter 5:query method
print('\n===COMPLEX QUERY:Good conditions===')
min_rainfall=600
good_conditions=df.query('rainfall_mm > @min_rainfall and fertilizer_kg>100')
print(good_conditions[['farm_id','crop','rainfall_mm','fertilizer_kg']])

#position-based selection
print('\n===FIRST 3 FARMS (iloc)===')
print(df.iloc[0:3])

#label-based selection
print('\n===SPECIFIC COLUMNS (loc)===')
print(df.loc[:,['farm_id','crop','yield_per_ha']])

#combined filtering and selection
print('\n===TOP PERFORMERS-SELECTED COLUMNS===')
top=df[df['yield_per_ha']>4.5][['farm_id','crop','yield_per_ha']]
print(top)
# Out:
# original dataset:
#   farm_id   crop  yield_tons  rainfall_mm  fertilizer_kg  soil_pH  \
# 0    F001  wheat         180          450            120      6.5
# 1    F002   rice         228          820            150      5.8
# 2    F003   corn         416          680            200      6.2
# 3    F004  wheat         164          420            110      6.7
# 4    F005   rice         245          850            160      5.9
# 5    F006   corn         390          710            195      6.1
# 6    F007  wheat         195          480            125      6.4
#
#    yield_per_ha
# 0           3.6
# 1           4.6
# 2           8.3
# 3           3.3
# 4           4.9
# 5           7.8
# 6           3.9
#
# ===HIGH YIELD FARMS(>200 tons)===
#   farm_id  crop  yield_tons  rainfall_mm  fertilizer_kg  soil_pH  yield_per_ha
# 1    F002  rice         228          820            150      5.8           4.6
# 2    F003  corn         416          680            200      6.2           8.3
# ...

# %%
#HANDLING MISSING DATA
import pandas as pd
import numpy as np
data=pd.DataFrame({
    "name":["alice","bob","charlie","david","eva","frank","george"],
    "department":["HR","IT","IT","FINANCE",np.nan,"HR","FINANCE"],
    "salary":[50000,np.nan,70000,70000,52000,np.nan,60000],
    "experience":[2,5,4,6,3,6,7]
})
print(data)
data.isnull()
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 1      bob         IT      NaN           5
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 4      eva        NaN  52000.0           3
# 5    frank         HR      NaN           6
# 6   george    FINANCE  60000.0           7
#     name  department  salary  experience
# 0  False       False   False       False
# 1  False       False    True       False
# 2  False       False   False       False
# 3  False       False   False       False
# 4  False        True   False       False
# 5  False       False    True       False
# 6  False       False   False       False

# %%
data.isna()
# Out:
#     name  department  salary  experience
# 0  False       False   False       False
# 1  False       False    True       False
# 2  False       False   False       False
# 3  False       False   False       False
# 4  False        True   False       False
# 5  False       False    True       False
# 6  False       False   False       False

# %%
#count the missing value
data.isna().sum()
# Out:
# name          0
# department    1
# salary        2
# experience    0
# dtype: int64

# %%
#total missing value
data.isna().sum().sum()
# Out:
# np.int64(3)

# %%
data.dropna()
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 6   george    FINANCE  60000.0           7

# %%
#drops only when all the row values are nan
data.dropna(how ='all')
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 1      bob         IT      NaN           5
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 4      eva        NaN  52000.0           3
# 5    frank         HR      NaN           6
# 6   george    FINANCE  60000.0           7

# %%
#drops rows with any nan(axis =0)
data.dropna(axis=0)
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 6   george    FINANCE  60000.0           7

# %%
#axis=1 drops column wise
data.dropna(axis=1)
# Out:
#       name  experience
# 0    alice           2
# 1      bob           5
# 2  charlie           4
# 3    david           6
# 4      eva           3
# 5    frank           6
# 6   george           7

# %%
#drops with specific column
data.dropna(subset=['salary'])
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 4      eva        NaN  52000.0           3
# 6   george    FINANCE  60000.0           7

# %%
#keep rows with atleast 3 non nan values
data.dropna(thresh=4)
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 6   george    FINANCE  60000.0           7

# %%
#fill with constant
data.fillna(0)
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 1      bob         IT      0.0           5
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 4      eva          0  52000.0           3
# 5    frank         HR      0.0           6
# 6   george    FINANCE  60000.0           7

# %%
#fill with mean
data['salary','experience'].fillna(data['salary','experience'].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('salary', 'experience')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3321361681.py in <cell line: 0>()
#       1 #fill with mean
# ...

# %%
data['salary'].fillna(data['experience'].mean())
# Out:
# 0    50000.000000
# 1        4.714286
# 2    70000.000000
# 3    70000.000000
# 4    52000.000000
# 5        4.714286
# 6    60000.000000
# Name: salary, dtype: float64

# %%
data['salary'].fillna(data['salary'].mean())
# Out:
# 0    50000.0
# 1    60400.0
# 2    70000.0
# 3    70000.0
# 4    52000.0
# 5    60400.0
# 6    60000.0
# Name: salary, dtype: float64

# %%
#different values per column
data.fillna({'department':0,'salary':'unknown'})
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 1      bob         IT  unknown           5
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 4      eva          0  52000.0           3
# 5    frank         HR  unknown           6
# 6   george    FINANCE  60000.0           7

# %%
data.fillna({'department':'unknown','salary':0})
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 1      bob         IT      0.0           5
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 4      eva    unknown  52000.0           3
# 5    frank         HR      0.0           6
# 6   george    FINANCE  60000.0           7

# %%
data.fillna({'department':'unknown','salary':60000})
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 1      bob         IT  60000.0           5
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 4      eva    unknown  52000.0           3
# 5    frank         HR  60000.0           6
# 6   george    FINANCE  60000.0           7

# %%
#forward fill
data.ffill()
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 1      bob         IT  50000.0           5
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 4      eva    FINANCE  52000.0           3
# 5    frank         HR  52000.0           6
# 6   george    FINANCE  60000.0           7

# %%
#backward fill
data.bfill()
# Out:
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 1      bob         IT  70000.0           5
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 4      eva         HR  52000.0           3
# 5    frank         HR  60000.0           6
# 6   george    FINANCE  60000.0           7

# %%
#interpolation
data.interpolate()
# Out:
# /tmp/ipython-input-2375145604.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data.interpolate()
#       name department   salary  experience
# 0    alice         HR  50000.0           2
# 1      bob         IT  60000.0           5
# 2  charlie         IT  70000.0           4
# 3    david    FINANCE  70000.0           6
# 4      eva        NaN  52000.0           3
# 5    frank         HR  56000.0           6
# 6   george    FINANCE  60000.0           7

# %%
df=pd.DataFrame({
    "name": ["mandu","varu","pragna","nihu","druthi"],
    "marks": [100,200,300,400,np.nan]
})
df.interpolate()
# Out:
# /tmp/ipython-input-4111700955.py:5: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#      name  marks
# 0   mandu  100.0
# 1    varu  200.0
# 2  pragna  300.0
# 3    nihu  400.0
# 4  druthi  400.0

# %%
import pandas as pd
import numpy as np

# Agricultural data with missing values
data = {
    'Farm_ID': ['F001', 'F002', 'F003', 'F004', 'F005', 'F006'],
    'Crop': ['Wheat', 'Rice', np.nan, 'Wheat', 'Corn', 'Rice'],
    'Yield_tons': [180, np.nan, 416, 164, np.nan, 228],
    'Rainfall_mm': [450, 820, np.nan, 420, 710, 850],
    'Fertilizer_kg': [120, 150, 200, np.nan, 195, 160],
    'Soil_pH': [6.5, 5.8, 6.2, 6.7, np.nan, 5.9]
}

df=pd.DataFrame(data)
print('original data with missing values:')
print(df)

print('\n===MISSING VALUE ANALYSIS===')
print('\nMissing values per column:')
print(df.isna().sum())
print(f'Total missing values: {df.isna().sum().sum()}')
print(f'Percentage of missing data:{(df.isna().sum().sum()/df.size*100):.2f}%')

print('\n===ROWS WITH MISSING DATA===')
rows_with_missing=df[df.isna().any(axis=1)]
print(rows_with_missing)

#Strategy 1: Drop rows with missing values
print('\n===STARTEGY 1: DROP MISSING ROWS===')
df_dropped=df.dropna()
print(f'Original shape: {df.shape}')
print(f'After dropping: {df_dropped.shape}')
print(df_dropped)

#Strategy 2: Fill with mean/median
print('\n===STRATEGY 2: FILL WITH STATISTICS===')
df_filled=df.copy()
#Fill numeric columns with mean
df_filled['Yield_tons']=df_filled['Yield_tons'].fillna(df_filled['Yield_tons'].mean())
df_filled['Rainfall_mm']=df_filled['Rainfall_mm'].fillna(df_filled['Rainfall_mm'].median())
df_filled['Fertilizer_kg']=df_filled['Fertilizer_kg'].fillna(df_filled['Fertilizer_kg'].mean())
df_filled['Soil_pH']=df_filled['Soil_pH'].fillna(df_filled['Soil_pH'].mean())
# Fill categorical with mode
df_filled['Crop']=df_filled['Crop'].fillna(df_filled['Crop'].mode()[0])
print(df_filled)

# Strategy 3: Forward fill (useful for time series)
print('\n=== STRATEGY 3: FORWARD FILL ===')
df_ffill = df.ffill()
print(df_ffill)

#Strategy 4: Custom fill per column
print('\n===STRATEGY 4: CUSTOM FILL===')
df_custom=df.fillna({
    'Crop': 'Unknown',
    'Yield_tons': df['Yield_tons'].median(),
    'Rainfall_mm': 650,  # Regional average
    'Fertilizer_kg': 150,  # Standard recommendation
    'Soil_pH': 6.3  # Neutral pH
})
print(df_custom)

print('\n===VERIFICATION===')
print(f'Missing values after treatment:{df_custom.isna().sum().sum()}')
# Out:
# original data with missing values:
#   Farm_ID   Crop  Yield_tons  Rainfall_mm  Fertilizer_kg  Soil_pH
# 0    F001  Wheat       180.0        450.0          120.0      6.5
# 1    F002   Rice         NaN        820.0          150.0      5.8
# 2    F003    NaN       416.0          NaN          200.0      6.2
# 3    F004  Wheat       164.0        420.0            NaN      6.7
# 4    F005   Corn         NaN        710.0          195.0      NaN
# 5    F006   Rice       228.0        850.0          160.0      5.9
#
# ===MISSING VALUE ANALYSIS===
#
# Missing values per column:
# Farm_ID          0
# Crop             1
# Yield_tons       2
# Rainfall_mm      1
# Fertilizer_kg    1
# Soil_pH          1
# dtype: int64
# Total missing values: 6
# Percentage of missing data:16.67%
#
# ===ROWS WITH MISSING DATA===
#   Farm_ID   Crop  Yield_tons  Rainfall_mm  Fertilizer_kg  Soil_pH
# 1    F002   Rice         NaN        820.0          150.0      5.8
# ...

# %%
#data aggregation and grouping
import pandas as pd

# Multi-year farm data
data = {
    'Year': [2020, 2020, 2020, 2021, 2021, 2021, 2022, 2022, 2022, 2023, 2023, 2023],
    'Region': ['North', 'South', 'East', 'North', 'South', 'East',
               'North', 'South', 'East', 'North', 'South', 'East'],
    'Crop': ['Wheat', 'Rice', 'Corn', 'Wheat', 'Rice', 'Corn',
             'Wheat', 'Rice', 'Corn', 'Wheat', 'Rice', 'Corn'],
    'Yield_tons': [180, 228, 416, 195, 245, 430, 210, 250, 445, 225, 260, 455],
    'Area_ha': [50, 45, 55, 52, 46, 56, 54, 48, 57, 55, 49, 58],
    'Cost_thousands': [85, 95, 180, 90, 100, 190, 95, 105, 195, 100, 110, 200]
}

df=pd.DataFrame(data)

print('Agricultural dataset:')
print(df)

#Group by region
print('\n===ANALYSIS BY REGION===')
region_stats=df.groupby('Region').agg({
    'Yield_tons': ['sum', 'mean', 'std'],
    'Area_ha': 'sum',
    'Cost_thousands': 'sum'
})
print(region_stats)

#Group by crop
print('\n===ANALYSIS BY CROP===')
crop_stats=df.groupby('Crop').agg({
    'Yield_tons': ['mean', 'min', 'max'],
    'Cost_thousands': 'mean'
}).round(2)
print(crop_stats)

# Multiple grouping (Region and Crop)
print('\n=== REGION-CROP ANALYSIS ===')
region_crop = df.groupby(['Region', 'Crop'])['Yield_tons'].mean().round(2)
print(region_crop)

# Year-over-year growth
print('\n=== YEARLY TRENDS ===')
yearly = df.groupby('Year').agg({
    'Yield_tons': 'sum',
    'Area_ha': 'sum'
})
yearly['Yield_per_ha'] = (yearly['Yield_tons'] / yearly['Area_ha']).round(2)
print(yearly)

# Transform: Add group mean to each row
df['Region_Avg_Yield'] = df.groupby('Region')['Yield_tons'].transform('mean').round(2)
df['Crop_Avg_Yield'] = df.groupby('Crop')['Yield_tons'].transform('mean').round(2)

print('\n=== DATASET WITH GROUP AVERAGES ===')
print(df[['Year', 'Region', 'Crop', 'Yield_tons',
          'Region_Avg_Yield', 'Crop_Avg_Yield']].head(6))


# Pivot table
print('\n=== PIVOT TABLE: Average Yield by Region and Crop ===')
pivot = df.pivot_table(values='Yield_tons',
                       index='Region',
                       columns='Crop',
                       aggfunc='mean').round(2)
print(pivot)

# Filter groups with high performance
print('\n=== HIGH PERFORMING REGIONS (Avg Yield > 300) ===')
high_regions = df.groupby('Region').filter(lambda x: x['Yield_tons'].mean() > 300)
print(high_regions[['Region', 'Crop', 'Yield_tons']].drop_duplicates('Region'))
# Out:
# Agricultural dataset:
#     Year Region   Crop  Yield_tons  Area_ha  Cost_thousands
# 0   2020  North  Wheat         180       50              85
# 1   2020  South   Rice         228       45              95
# 2   2020   East   Corn         416       55             180
# 3   2021  North  Wheat         195       52              90
# 4   2021  South   Rice         245       46             100
# 5   2021   East   Corn         430       56             190
# 6   2022  North  Wheat         210       54              95
# 7   2022  South   Rice         250       48             105
# 8   2022   East   Corn         445       57             195
# 9   2023  North  Wheat         225       55             100
# 10  2023  South   Rice         260       49             110
# 11  2023   East   Corn         455       58             200
#
# ===ANALYSIS BY REGION===
#        Yield_tons                    Area_ha Cost_thousands
#               sum    mean        std     sum            sum
# Region
# ...

# %%
import pandas as pd
data={
    'department':['HR','Sales','IT','Sales','IT','HR','Sales'],
    'employee':['A','B','C','D','E','F','G'],
    'salary':[50000,60000,45000,48000,70000,72000,71000],
    'experience':[2,4,3,5,6,7,5]
}
df=pd.DataFrame(data)
print(df)

df1=df.groupby(['department','experience']).sum()
print(df1)

df2=df.groupby('experience').sum()
print(df2)

df3=df.groupby('department').sum()
print(df3)

df4=df.groupby('department')['salary'].sum()
print(df4)

df5=df.groupby('experience')['salary'].mean()
print(df5)

df6=df.groupby('department')['salary'].mean()
print(df6)

df7=df.groupby('department')['experience'].mean()
print(df7)

df8=df.groupby('department')['employee'].count()
print(df8)


df9=df.groupby('department')['salary'].agg(['sum','mean','std'])
print(df9)

df10=df.groupby('department').agg({
    'salary':'sum', 'experience':'mean'
})
print(df10)

df11=df['dept_avg_salary']=df.groupby('department')['salary'].transform('mean')
print(df11)

df12=df.groupby('department').filter(lambda x:len(x)>2)
print(df12)

df.pivot_table(
values='salary',
index='department',
columns='experience',
aggfunc='mean'
)
# Out:
#   department employee  salary  experience
# 0         HR        A   50000           2
# 1      Sales        B   60000           4
# 2         IT        C   45000           3
# 3      Sales        D   48000           5
# 4         IT        E   70000           6
# 5         HR        F   72000           7
# 6      Sales        G   71000           5
#                       employee  salary
# department experience
# HR         2                 A   50000
#            7                 F   72000
# IT         3                 C   45000
#            6                 E   70000
# Sales      4                 B   60000
#            5                DG  119000
#             department employee  salary
# experience
# 2                   HR        A   50000
# 3                   IT        C   45000
# 4                Sales        B   60000
# 5           SalesSales       DG  119000
# 6                   IT        E   70000
# 7                   HR        F   72000
# ...

# %%
df1=df.groupby(['department','experience']).sum()
print(df1)
# Out:
#                       employee  salary
# department experience
# HR         2                 A   50000
#            7                 F   72000
# IT         3                 C   45000
#            6                 E   70000
# Sales      4                 B   60000
#            5                DG  119000

# %%
df2=df.groupby('experience').sum()
print(df2)
# Out:
#             department employee  salary
# experience
# 2                   HR        A   50000
# 3                   IT        C   45000
# 4                Sales        B   60000
# 5           SalesSales       DG  119000
# 6                   IT        E   70000
# 7                   HR        F   72000

# %%
df3=df.groupby('department').sum()
print(df3)
# Out:
#            employee  salary  experience
# department
# HR               AF  122000           9
# IT               CE  115000           9
# Sales           BDG  179000          14

# %%
df4=df.groupby('department')['salary'].sum()
print(df4)
# Out:
# department
# HR       122000
# IT       115000
# Sales    179000
# Name: salary, dtype: int64

# %%
df5=df.groupby('experience')['salary'].mean()
print(df5)
# Out:
# experience
# 2    50000.0
# 3    45000.0
# 4    60000.0
# 5    59500.0
# 6    70000.0
# 7    72000.0
# Name: salary, dtype: float64

# %%
df6=df.groupby('department')['salary'].mean()
print(df6)
# Out:
# department
# HR       61000.000000
# IT       57500.000000
# Sales    59666.666667
# Name: salary, dtype: float64

# %%
df7=df.groupby('department')['experience'].mean()
print(df7)
# Out:
# department
# HR       4.500000
# IT       4.500000
# Sales    4.666667
# Name: experience, dtype: float64

# %%
df8=df.groupby('department')['employee'].count()
print(df8)
# Out:
# department
# HR       2
# IT       2
# Sales    3
# Name: employee, dtype: int64

# %%
df9=df.groupby('department')['salary'].agg(['sum','mean','std'])
print(df9)
# Out:
#                sum          mean           std
# department
# HR          122000  61000.000000  15556.349186
# IT          115000  57500.000000  17677.669530
# Sales       179000  59666.666667  11503.622618

# %%
df.groupby('department')['salary'].agg(['sum','mean','std'])
# Out:
#                sum          mean           std
# department
# HR          122000  61000.000000  15556.349186
# IT          115000  57500.000000  17677.669530
# Sales       179000  59666.666667  11503.622618

# %%
df10=df.groupby('department').agg({
    'salary':'sum', 'experience':'mean'
})
print(df10)
# Out:
#             salary  experience
# department
# HR          122000    4.500000
# IT          115000    4.500000
# Sales       179000    4.666667

# %%
df11=df['dept_avg_salary']=df.groupby('department')['salary'].transform('mean')
print(df11)
print(df)
# Out:
# 0    61000.000000
# 1    59666.666667
# 2    57500.000000
# 3    59666.666667
# 4    57500.000000
# 5    61000.000000
# 6    59666.666667
# Name: salary, dtype: float64
#   department employee  salary  experience  dept_avg_salary
# 0         HR        A   50000           2     61000.000000
# 1      Sales        B   60000           4     59666.666667
# 2         IT        C   45000           3     57500.000000
# 3      Sales        D   48000           5     59666.666667
# 4         IT        E   70000           6     57500.000000
# 5         HR        F   72000           7     61000.000000
# 6      Sales        G   71000           5     59666.666667

# %%
df12=df.groupby('department').filter(lambda x:len(x)>2)
print(df12)
# Out:
#   department employee  salary  experience  dept_avg_salary
# 1      Sales        B   60000           4     59666.666667
# 3      Sales        D   48000           5     59666.666667
# 6      Sales        G   71000           5     59666.666667

# %%
df.pivot_table(
values='salary',
index='department',
columns='experience',
aggfunc='mean'
)
# Out:
# experience        2        3        4        5        6        7
# department
# HR          50000.0      NaN      NaN      NaN      NaN  72000.0
# IT              NaN  45000.0      NaN      NaN  70000.0      NaN
# Sales           NaN      NaN  60000.0  59500.0      NaN      NaN

# %%
#new one
import pandas as pd
data={
    'name':['arun','bhuvan','chandan','deepthi','ethan','farhan','gowri'],
    'crop':['ragi','paddy','maize','ragi','paddy','maize','wheat'],
    'season':['kharif','rabi','zaid','kharif','rabi','zaid','kharif'],
    'crop area':[2,4,6,5,7,8,9],
    'yield':[200,390,680,770,558,270,655],
    'no of crops grown':[3,3,2,4,2,1,1]
}
df=pd.DataFrame(data)
print(df)
# Out:
#       name   crop  season  crop area  yield  no of crops grown
# 0     arun   ragi  kharif          2    200                  3
# 1   bhuvan  paddy    rabi          4    390                  3
# 2  chandan  maize    zaid          6    680                  2
# 3  deepthi   ragi  kharif          5    770                  4
# 4    ethan  paddy    rabi          7    558                  2
# 5   farhan  maize    zaid          8    270                  1
# 6    gowri  wheat  kharif          9    655                  1

# %%
df1=df.groupby('crop').sum()
print(df1)
# Out:
#                 name        season  crop area  yield  no of crops grown
# crop
# maize  chandanfarhan      zaidzaid         14    950                  3
# paddy    bhuvanethan      rabirabi         11    948                  5
# ragi     arundeepthi  kharifkharif          7    970                  7
# wheat          gowri        kharif          9    655                  1

# %%
df2=df.groupby('crop')['crop area'].sum()
print(df2)
# Out:
# crop
# maize    14
# paddy    11
# ragi      7
# wheat     9
# Name: crop area, dtype: int64

# %%
df3=df.groupby('season')['yield'].sum()
print(df3)
# Out:
# season
# kharif    1625
# rabi       948
# zaid       950
# Name: yield, dtype: int64

# %%
df4=df.groupby('crop')['crop area'].mean()
print(df4)
# Out:
# crop
# maize    7.0
# paddy    5.5
# ragi     3.5
# wheat    9.0
# Name: crop area, dtype: float64

# %%
df5=df.groupby('name').sum()
print(df5)
# Out:
#           crop  season  crop area  yield  no of crops grown
# name
# arun      ragi  kharif          2    200                  3
# bhuvan   paddy    rabi          4    390                  3
# chandan  maize    zaid          6    680                  2
# deepthi   ragi  kharif          5    770                  4
# ethan    paddy    rabi          7    558                  2
# farhan   maize    zaid          8    270                  1
# gowri    wheat  kharif          9    655                  1

# %%
df6=df.groupby('crop').sum()
print(df6)
# Out:
#                 name        season  crop area  yield  no of crops grown
# crop
# maize  chandanfarhan      zaidzaid         14    950                  3
# paddy    bhuvanethan      rabirabi         11    948                  5
# ragi     arundeepthi  kharifkharif          7    970                  7
# wheat          gowri        kharif          9    655                  1

# %%
df7=df.groupby('crop')['crop area'].mean()
print(df7)
# Out:
# crop
# maize    7.0
# paddy    5.5
# ragi     3.5
# wheat    9.0
# Name: crop area, dtype: float64

# %%
df8=df.groupby('name')['crop'].count()
print(df8)
# Out:
# name
# arun       1
# bhuvan     1
# chandan    1
# deepthi    1
# ethan      1
# farhan     1
# gowri      1
# Name: crop, dtype: int64

# %%
df9=df.groupby('season')['crop'].count()
print(df9)
# Out:
# season
# kharif    3
# rabi      2
# zaid      2
# Name: crop, dtype: int64

# %%
df10=df.groupby('crop')['7']
