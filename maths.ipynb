# %%
# Mathematical concepts applied to farming
import math
#1. Simple Equation: Yield Prediction
def predict_yield(rainfall,fertilizer,base_yield=2000):
  """
  simple linear model:yield = base+(rain_effect)+(fert_effect)
  This is the foundation of regression
  """
  rain_coefficient=10 #kg per mm of rain
  fert_coefficient=15 #kg per unit of fertilizer
  predicted = base_yield + (rainfall * rain_coefficient)+(fertilizer * fert_coefficient)
  return predicted

print("===Yield Prediction (Linear Model)===")
print(f"100mm rain, 50 units fert: {predict_yield(100,50)} kg/hectare")

#2. Optimization : finding best input levels
def profit_function(fertilizer_amount,price_per_kg=20,fert_cost_per_unit=50):
  """
  find fertilizer amount that maximizes profit
  yield increases with fertilizer but with diminishing returns
  """
  # Diminishing returns: sqrt function
  yield_increase=500*math.sqrt(fertilizer_amount)
  revenue=yield_increase * price_per_kg
  cost= fertilizer_amount* fert_cost_per_unit
  profit= revenue-cost
  return profit

print("\n===Optimization: Best Fertilizer Amount===")
for fert in[10,25,50,100,150]:
  profit=profit_function(fert)
  print(f"Fertilizer: {fert} units -> Profit: Rs{profit:.0f}")
# Out:
# ===Yield Prediction (Linear Model)===
# 100mm rain, 50 units fert: 3750 kg/hectare
#
# ===Optimization: Best Fertilizer Amount===
# Fertilizer: 10 units -> Profit: Rs31123
# Fertilizer: 25 units -> Profit: Rs48750
# Fertilizer: 50 units -> Profit: Rs68211
# Fertilizer: 100 units -> Profit: Rs95000
# Fertilizer: 150 units -> Profit: Rs114974

# %%
# Mathematical concepts applied to farming
import math
#1. Simple Equation: Yield Prediction
def predict_yield(rainfall,fertilizer,base_yield=2000):
  """
  simple linear model:yield = base+(rain_effect)+(fert_effect)
  This is the foundation of regression
  """
  rain_coefficient=10 #kg per mm of rain
  fert_coefficient=15 #kg per unit of fertilizer
  predicted = base_yield + (rainfall * rain_coefficient)+(fertilizer * fert_coefficient)
  return predicted

print("===Yield Prediction (Linear Model)===")
print(f"100mm rain, 50 units fert: {predict_yield(100,50)} kg/hectare")
# Out:
# ===Yield Prediction (Linear Model)===
# 100mm rain, 50 units fert: 3750 kg/hectare

# %%
#2. Optimization : finding best input levels
def profit_function(fertilizer_amount,price_per_kg,fert_cost_per_unit):
  """
  find fertilizer amount that maximizes profit
  yield increases with fertilizer but with diminishing returns
  """
  # Diminishing returns: sqrt function
  yield_increase=500*math.sqrt(fertilizer_amount)
  revenue=yield_increase * price_per_kg
  cost= fertilizer_amount* fert_cost_per_unit
  profit= revenue-cost
  return profit

print("\n===Optimization: Best Fertilizer Amount===")
for fert in[10,25,50,100,150]:
  profit=profit_function(fert,20,50)
  print(f"Fertilizer: {fert} units -> Profit: Rs{profit:.0f}")
# Out:
# ===Optimization: Best Fertilizer Amount===
# Fertilizer: 10 units -> Profit: Rs31123
# Fertilizer: 25 units -> Profit: Rs48750
# Fertilizer: 50 units -> Profit: Rs68211
# Fertilizer: 100 units -> Profit: Rs95000
# Fertilizer: 150 units -> Profit: Rs114974

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
#1. User Input for 10 values
rainfall_list=[]
fertilizer_list=[]

print("Enter 10 rainfall values(in mm):")
for i in range(10):
  val=float(input(f"Rainfall {i+1}:"))
  rainfall_list.append(val)

print("Enter 10 fertilizer values (in units):")
for i in range(10):
  val = float(input(f"fertilizer {i+1}:"))
  fertilizer_list.append(val)

def predict_yield(rainfall, fertilizer, base_yield=2000):
  rain_coefficient = 10 #kg per mm of rain
  fert_coefficient = 15 # kg per unit of fertilizer
  predicted = base_yield + (rainfall*rain_coefficient)+(fertilizer*fert_coefficient)
  return predicted
yield_list=[predict_yield(r,f)for r,f in zip(rainfall_list,fertilizer_list)]

def profit_function(fertilizer_amount, price_per_kg=20,fert_cost_per_unit=50):
  yield_increase=500*math.sqrt(fertilizer_amount)
  revenue=yield_increase*price_per_kg
  cost=fertilizer_amount*fert_cost_per_unit
  profit=revenue-cost
  return profit
profit_list=[profit_function(f) for f in fertilizer_list]

#display results
print("\n===Results===")
for i in range(10):
  print(f"Rainfall:{rainfall_list[i]}mm,Fertilizer:{fertilizer_list[i]} units -> Yield: {yield_list[i]:.2f} kg/ha, Profit: Rs{profit_list[i]:.2f}")
# Out:
# Enter 10 rainfall values(in mm):
# Rainfall 1:10
# Rainfall 2:20
# Rainfall 3:30
# Rainfall 4:40
# Rainfall 5:50
# Rainfall 6:60
# Rainfall 7:70
# Rainfall 8:80
# Rainfall 9:90
# Rainfall 10:100
# Enter 10 fertilizer values (in units):
# fertilizer 1:25
# fertilizer 2:22
# fertilizer 3:33
# fertilizer 4:44
# fertilizer 5:55
# fertilizer 6:32
# fertilizer 7:46
# fertilizer 8:57
# fertilizer 9:56
# fertilizer 10:54
#
# ===Results===
# Rainfall:10.0mm,Fertilizer:25.0 units -> Yield: 2475.00 kg/ha, Profit: Rs48750.00
# Rainfall:20.0mm,Fertilizer:22.0 units -> Yield: 2530.00 kg/ha, Profit: Rs45804.16
# Rainfall:30.0mm,Fertilizer:33.0 units -> Yield: 2795.00 kg/ha, Profit: Rs55795.63
# Rainfall:40.0mm,Fertilizer:44.0 units -> Yield: 3060.00 kg/ha, Profit: Rs64132.50
# Rainfall:50.0mm,Fertilizer:55.0 units -> Yield: 3325.00 kg/ha, Profit: Rs71411.98
# Rainfall:60.0mm,Fertilizer:32.0 units -> Yield: 3080.00 kg/ha, Profit: Rs54968.54
# Rainfall:70.0mm,Fertilizer:46.0 units -> Yield: 3390.00 kg/ha, Profit: Rs65523.30
# Rainfall:80.0mm,Fertilizer:57.0 units -> Yield: 3655.00 kg/ha, Profit: Rs72648.34
# Rainfall:90.0mm,Fertilizer:56.0 units -> Yield: 3740.00 kg/ha, Profit: Rs72033.15
# Rainfall:100.0mm,Fertilizer:54.0 units -> Yield: 3810.00 kg/ha, Profit: Rs70784.69
