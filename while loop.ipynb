# %%
count=1
while count<=5:
  print(count)
  count+=1
print("End of the program")
# Out:
# 1
# 2
# 3
# 4
# 5
# End of the program

# %%
water_level=20  #in percentage
while water_level<50:
  print("Irrigation ON-water Level:",water_level,"%")
  water_level+=5
print("sufficent water.Irrrigation OFF")
# Out:
# Irrigation ON-water Level: 20 %
# Irrigation ON-water Level: 25 %
# Irrigation ON-water Level: 30 %
# Irrigation ON-water Level: 35 %
# Irrigation ON-water Level: 40 %
# Irrigation ON-water Level: 45 %
# sufficent water.Irrrigation OFF

# %%
while True:
  print("this runs forever")
# Out:
# Streaming output truncated to the last 5000 lines.
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# this runs forever
# ...

# %%
#break
count=1
while True:
 print(count)
 if count==5:
   break
 count+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#continue
count=0
while count<5:
  count+=1
  if count==3:
     continue
  print(count)
# Out:
# 1
# 2
# 4
# 5

# %%
#while else
count=1
while count<=3:
  print(count)
  count+=1
else:
  print("Loop completed")
# Out:
# 1
# 2
# 3
# Loop completed

# %%
while True:
    # Accept pest count from the user
    pest_count = int(input("Enter pest count: "))

    # Check if the count is 0 to stop monitoring
    if pest_count == 0:
        print("Monitoring stopped")
        break
    else:
        print(f"Pest count recorded: {pest_count}")
# Out:
# Enter pest count: 10
# Pest count recorded: 10
# Enter pest count: 100
# Pest count recorded: 100
# Enter pest count: 87
# Pest count recorded: 87
# Enter pest count: 4
# Pest count recorded: 4
# Enter pest count: 48
# Pest count recorded: 48
# Enter pest count: 0
# Monitoring stopped
