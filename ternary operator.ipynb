# %%
yield_value=80
"good yield" if yield_value>70 else "poor yield"
# Out:
# 'good yield'

# %%
x=90
"A" if x>80 else "B" if x>60 else "C"
# Out:
# 'A'

# %%
x=55
if x>80:
   print("A")
elif x>60:
   print("B")
else:
   print("C")
# Out:
# C
