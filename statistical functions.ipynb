# %%
import numpy as np
#Rainfall data(mm) over 12 months
rainfall=np.array([45,52,68,120,180,220,195,160,110,75,58,40])
#corresponding crop yield(tons/tons)
yields=np.array([2.1,2.3,2.8,4.2,5.8,6.5,5.9,5.2,3.8,2.9,2.4,2.0])
print('==RAINFALL STATISTICS==')
print(f'mean:{np.mean(rainfall):.2f}mm')
print(f'median:{np.median(rainfall):.2f}mm')
print(f'std dev:{np.std(rainfall):.2f}mm')
print(f'variance:{np.var(rainfall):.2f}mm')
print(f'min:{np.min(rainfall)}mm(month{np.argmin(rainfall)+1})')
print(f'max:{np.max(rainfall)}mm(month{np.argmax(rainfall)+1})')
print(f'range:{np.ptp(rainfall)}mm')
print('\n==YIELD STATISTICS==')
print(f'mean:{np.mean(yields):.2f}tons/ha')
print(f'median:{np.median(yields):.2f}tons/ha')
print(f'std:{np.std(yields):.2f}tons/ha')
print('\n==PERCENTILES==')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip(percentiles,rainfall_percentiles):
  print(f'{p}th percentile rainfall:{val:.2f}mm')
print('\n==CORRELATIONS ANALYSIS==')
correlation_matrix=np.corrcoef(rainfall,yields)
correlation=correlation_matrix[0,1]
print(f'rainfall-yield correlation:{correlation:.4f}')
print('interpretation:Strong positive correlation' if correlation>0.7 else 'Moderate correlation' if correlation>0.4 else 'Weak correlation')
print('\n==CUMULATIVE RAINFALL==')
cumulative=np.cumsum(rainfall)
print('Month\tRainfall\tCumulative')
for month,(rain,cum)in enumerate (zip(rainfall,cumulative),1):
  print(f'{month}\t{rain}\t\t{cum}')
# Out:
# ==RAINFALL STATISTICS==
# mean:110.25mm
# median:92.50mm
# std dev:61.24mm
# variance:3750.52mm
# min:40mm(month12)
# max:220mm(month6)
# range:180mm
#
# ==YIELD STATISTICS==
# mean:3.82tons/ha
# median:3.35tons/ha
# std:1.58tons/ha
#
# ==PERCENTILES==
# 25th percentile rainfall:56.50mm
# 50th percentile rainfall:92.50mm
# 75th percentile rainfall:165.00mm
# 90th percentile rainfall:193.50mm
#
# ==CORRELATIONS ANALYSIS==
# rainfall-yield correlation:0.9983
# interpretation:Strong positive correlation
#
# ==CUMULATIVE RAINFALL==
# Month	Rainfall	Cumulative
# 1	45		45
# 2	52		97
# 3	68		165
# 4	120		285
# 5	180		465
# 6	220		685
# 7	195		880
# 8	160		1040
# 9	110		1150
# 10	75		1225
# 11	58		1283
# 12	40		1323

# %%
import numpy as np
#Rainfall data(mm) over 12 months
rainfall=np.array([45,52,68,120,180,220,195,160,110,75,58,40])
#corresponding crop yield(tons/tons)
yields=np.array([2.1,2.3,2.8,4.2,5.8,6.5,5.9,5.2,3.8,2.9,2.4,2.0])
print('==RAINFALL STATISTICS==')
print(f'mean:{np.mean(rainfall):.2f}mm')
print(f'median:{np.median(rainfall):.2f}mm')
print(f'std dev:{np.std(rainfall):.2f}mm')
print(f'variance:{np.var(rainfall):.2f}mm')
print(f'min:{np.min(rainfall)}mm(month{np.argmin(rainfall)+1})')
print(f'max:{np.max(rainfall)}mm(month{np.argmax(rainfall)+1})')
print(f'range:{np.ptp(rainfall)}mm')
print('\n==YIELD STATISTICS==')
print(f'mean:{np.mean(yields):.2f}tons/ha')
print(f'median:{np.median(yields):.2f}tons/ha')
print(f'std:{np.std(yields):.2f}tons/ha')
print('\n==PERCENTILES==')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip(percentiles,rainfall_percentiles):
  print(f'{p}th percentile rainfall:{val:.2f}mm')
print('\n==CORRELATIONS ANALYSIS==')
correlation_matrix=np.corrcoef(rainfall,yields)
correlation=correlation_matrix[0,1]
print(f'rainfall-yield correlation:{correlation:.4f}')
print('interpretation:Strong positive correlation' if correlation>0.7 else 'Moderate correlation' if correlation>0.4 else 'Weak correlation')
print('\n==CUMULATIVE RAINFALL==')
cumulative=np.cumsum(rainfall)
print('Rainfall\tCumulative')
for (rain,cum) in (zip(rainfall,cumulative)):
  print(f'{rain}\t{cum}')
# Out:
# ==RAINFALL STATISTICS==
# mean:110.25mm
# median:92.50mm
# std dev:61.24mm
# variance:3750.52mm
# min:40mm(month12)
# max:220mm(month6)
# range:180mm
#
# ==YIELD STATISTICS==
# mean:3.82tons/ha
# median:3.35tons/ha
# std:1.58tons/ha
#
# ==PERCENTILES==
# 25th percentile rainfall:56.50mm
# 50th percentile rainfall:92.50mm
# 75th percentile rainfall:165.00mm
# 90th percentile rainfall:193.50mm
#
# ==CORRELATIONS ANALYSIS==
# rainfall-yield correlation:0.9983
# interpretation:Strong positive correlation
#
# ==CUMULATIVE RAINFALL==
# Month	Rainfall	Cumulative
# 45	45
# 52	97
# 68	165
# 120	285
# 180	465
# 220	685
# 195	880
# 160	1040
# 110	1150
# 75	1225
# 58	1283
# 40	1323

# %%
#ASSIGNMENT
# Out:
# Enter the number of months:12
# Enter the amount of rain of the month1:40
# Enter the yield of the month1:30
# Enter the amount of rain of the month2:50
# Enter the yield of the month2:40
# Enter the amount of rain of the month3:60
# Enter the yield of the month3:50
# Enter the amount of rain of the month4:70
# Enter the yield of the month4:60
# Enter the amount of rain of the month5:80
# Enter the yield of the month5:70
# Enter the amount of rain of the month6:90
# Enter the yield of the month6:80
# Enter the amount of rain of the month7:100
# Enter the yield of the month7:90
# Enter the amount of rain of the month8:150
# Enter the yield of the month8:120
# Enter the amount of rain of the month9:50
# Enter the yield of the month9:80
# Enter the amount of rain of the month10:120
# Enter the yield of the month10:90
# Enter the amount of rain of the month11:180
# Enter the yield of the month11:90
# Enter the amount of rain of the month12:200
# Enter the yield of the month12:150
# [40, 50, 60, 70, 80, 90, 100, 150, 50, 120, 180, 200]
# [30, 40, 50, 60, 70, 80, 90, 120, 80, 90, 90, 150]
# [ 40  50  60  70  80  90 100 150  50 120 180 200]
# [ 30  40  50  60  70  80  90 120  80  90  90 150]

# %%
print('==RAINFALL STATISTICS==')
print(f'mean:{np.mean(rainfall):.2f}mm')
print(f'median:{np.median(rainfall):.2f}mm')
print(f'std dev:{np.std(rainfall):.2f}mm')
print(f'variance:{np.var(rainfall):.2f}mm')
print(f'min:{np.min(rainfall)}mm(month{np.argmin(rainfall)+1})')
print(f'max:{np.max(rainfall)}mm(month{np.argmax(rainfall)+1})')
print(f'range:{np.ptp(rainfall)}mm')
print('\n==YIELD STATISTICS==')
print(f'mean:{np.mean(yields):.2f}tons/ha')
print(f'median:{np.median(yields):.2f}tons/ha')
print(f'std:{np.std(yields):.2f}tons/ha')
# Out:
# ==RAINFALL STATISTICS==
# mean:99.17mm
# median:85.00mm
# std dev:50.74mm
# variance:2574.31mm
# min:40mm(month1)
# max:200mm(month12)
# range:160mm
#
# ==YIELD STATISTICS==
# mean:79.17tons/ha
# median:80.00tons/ha
# std:32.00tons/ha

# %%
print('\n==PERCENTILES==')
percentiles=[25,50,75,90]
rainfall_percentiles=np.percentile(rainfall,percentiles)
for p,val in zip(percentiles,rainfall_percentiles):
  print(f'{p}th percentile rainfall:{val:.2f}mm')
# Out:
# ==PERCENTILES==
# 25th percentile rainfall:57.50mm
# 50th percentile rainfall:85.00mm
# 75th percentile rainfall:127.50mm
# 90th percentile rainfall:177.00mm

# %%
import numpy as np
no_of_months=int(input("Enter the number of months:"))
rainfall=[]
yields=[]
for i in range(1,no_of_months+1):
  rain=int(input(f"Enter the amount of rain of the month{i}:"))
  rainfall.append(rain)
  month_yield=int(input(f"Enter the yield of the month{i}:"))
  yields.append(month_yield)
print(rainfall)
print(yields)
rain_data=np.array(rainfall)
yield_data=np.array(yields)
print(rain_data)
print(yield_data)
print('==RAINFALL STATS==')
print(f'mean')
