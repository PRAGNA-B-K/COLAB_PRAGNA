# %%
#index () method
thislist=["apple","banana","cherry","banana"]
index_value=thislist.index("banana")
print("Index of banana:",index_value)
# Out:
# Index of banana: 1

# %%
#count() method
thislist=["apple","banana","apple","cherry","apple"]
count_value=thislist.count("apple")
print("count of apple:",count_value)
# Out:
# count of apple: 3

# %%
#reverse() method
thislist=["orange","mango","kiwi","banana"]
print("original list:",thislist)
thislist.reverse()
print("Reversed list:",thislist)
# Out:
# original list: ['orange', 'mango', 'kiwi', 'banana']
# Reversed list: ['banana', 'kiwi', 'mango', 'orange']

# %%
#reversed
original_list=[1,2,3,4,5]
reversed_iterator=reversed(original_list)
reversed_list=list(reversed_iterator)
print(reversed_list)
# Out:
# [5, 4, 3, 2, 1]

# %%
#List Length
thislist=["apple","banana","cherry"]
print(len(thislist))
# Out:
# 3

# %%
#List items-Data types
list1=["apple","banana","cherry"]
list2=[1,5,7,9,3]
list3=[True,False,False]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
list1=["apple","cherry","banana"]
list2=[1,5,7,9,3]
list3=[True,False,False]
list2.sort()
list1.sort()
list3.sort()
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 3, 5, 7, 9]
# [False, False, True]

# %%
list1=["apple","banana","cherry"]
for item in range(len(list1)):
  print(item)
# Out:
# 0
# 1
# 2

# %%
list1=["apple","banana","cherry"]
for item in range(len(list1)):
   print(list1[item])
# Out:
# apple
# banana
# cherry

# %%
#type()
x=10
y=11.5
mylist=["apple","banana","cherry"]
print(type(x))
print(type(y))
print(type(mylist))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'list'>

# %%
#type()
x=10
y=11.5
mylist="apple"
print(type(x))
print(type(y))
print(type(mylist))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
list1=["pragna","kruthi"]
print(list1)
# Out:
# ['pragna', 'kruthi']

# %%
thislist=["apple","banana","cherry","banana"]
print("original list:",thislist)
thislist.insert(1,"kiwi")
print("insert:",thislist)
# Out:
# original list: ['apple', 'banana', 'cherry', 'banana']
# insert: ['apple', 'kiwi', 'banana', 'cherry', 'banana']

# %%
thislist=["apple","banana","cherry","banana"]
print("original list:",thislist)
thislist.pop(1)
thislist.insert(1,"kiwi")
print("pop:",thislist)
# Out:
# original list: ['apple', 'banana', 'cherry', 'banana']
# pop: ['apple', 'kiwi', 'cherry', 'banana']

# %%
dates=[15,29,23]
names=["kruthi","nanditha","pragna"]
dates.extend(names)
print("extended list:",dates)
# Out:
# extended list: [15, 29, 23, 'kruthi', 'nanditha', 'pragna']

# %%
thislist=["apple","banana","cherry","banana"]
print("original list:",thislist)
thislist.remove(banana)
print("insert:",thislist)
