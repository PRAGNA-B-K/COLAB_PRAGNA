# %%
import pandas as pd
mydataset={
    'cars':["BMW","VOLVO","FORD"],
    'passings':[3,7,2]
}
myvar=pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  VOLVO         7
# 2   FORD         2

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
import pandas as pd
a=[1,7,3]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    3
# dtype: int64

# %%
import pandas as pd
a=[1,7,3]
myvar=pd.Series(a,index=["x","y","z"])
print(myvar)
print(myvar["y"])
# Out:
# x    1
# y    7
# z    3
# dtype: int64
# 7

# %%
import pandas as pd
a=[1,2,9]
myvar=pd.Series(a,index=[100,200,300])
print(myvar)
print(myvar[200])
# Out:
# 100    1
# 200    2
# 300    9
# dtype: int64
# 2

# %%
import pandas as pd
s=pd.Series([10,20,30,40,50])
for val in s:
 val=pd.Series(s,index=["a","b","c","d","e"])
 print(s,val)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64 a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# dtype: float64
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64 a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# dtype: float64
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64 a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# dtype: float64
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64 a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# dtype: float64
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64 a   NaN
# b   NaN
# c   NaN
# d   NaN
# e   NaN
# dtype: float64

# %%
import pandas as pd
s=pd.Series([10,20,30,40,50])
for val in s:
 print(val)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
for idx,val in s.items():
  print(idx,val)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50

# %%
import pandas as pd
s=pd.Series([10,20,30,40,50])
for idx,val in s.items():
  print(idx,val)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40
# 4 50

# %%
import pandas as pd
s=pd.Series([100,300,200],index=["a","b","c"])
print(s)
# Out:
# a    100
# b    300
# c    200
# dtype: int64

# %%
for label,value in s.items():
  print(label,value)
# Out:
# a 100
# b 300
# c 200

# %%
import pandas as pd
s=pd.Series([10,20,30,40,50])
print(label,value)
# Out:
# 4 50

# %%
for label in s.index:
  print(label)
for value in s.values:
  print(value)
# Out:
# 0
# 1
# 2
# 3
# 4
# 10
# 20
# 30
# 40
# 50

# %%
import pandas as pd
calories=({"day1":420,"day2":380,"day3":390})
myvar=pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
import pandas as pd
data={
    "calories":[309,290,400],
    "duration":[20,30,40]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       309        20
# 1       290        30
# 2       400        40

# %%
print(df.loc[0])
print(df.loc[1])
print(df.loc[2])
# Out:
# calories    309
# duration     20
# Name: 0, dtype: int64
# calories    290
# duration     30
# Name: 1, dtype: int64
# calories    400
# duration     40
# Name: 2, dtype: int64

# %%
print(df.loc[[0,1]])
print(df.loc[[1,1]])
# Out:
#    calories  duration
# 0       309        20
# 1       290        30
#    calories  duration
# 1       290        30
# 1       290        30

# %%
import pandas as pd
data={
    "calories":[300,400,439],
    "duration":[20,30,44]
}
df = pd.DataFrame(data,index=["day1","day2","day3"])
print(df)
# Out:
#       calories  duration
# day1       300        20
# day2       400        30
# day3       439        44

# %%
import pandas as pd
data={
    "calories":[300,400,439],
    "duration":[20,30,44]
}
df = pd.DataFrame(data,index=["day1","day2","day3","day4"])
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-125269970.py in <cell line: 0>()
#       4     "duration":[20,30,44]
#       5 }
# ----> 6 df = pd.DataFrame(data,index=["day1","day2","day3","day4"])
#       7 print(df)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
import pandas as pd
data={
    "calories":[300,400,439,699],
    "duration":[20,30,44]
}
df = pd.DataFrame(data,index=["day1","day2","day3"])
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3348557612.py in <cell line: 0>()
#       4     "duration":[20,30,44]
#       5 }
# ----> 6 df = pd.DataFrame(data,index=["day1","day2","day3"])
#       7 print(df)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
print(df.loc["day2"])
# Out:
# calories    400
# duration     30
# Name: day2, dtype: int64

# %%
print(df.loc[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2346044567.py in <cell line: 0>()
# ----> 1 print(df.loc[0])
#
# ...

# %%
import pandas as pd
data={
    "name":["mandara","varun","pragna"],
    "age":[28,26,23],
    "marks":[90,90,90]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       name  age  marks
# 0  mandara   28     90
# 1    varun   26     90
# 2   pragna   23     90

# %%
import pandas as pd
data={
    "name":["mandara","varun","pragna"],
    "age":[28,26,23],
    "marks":[97,94,91]
}
df = pd.DataFrame(data,columns=["name","age","marks"])
print(df)
# Out:
#       name  age  marks
# 0  mandara   28     97
# 1    varun   26     94
# 2   pragna   23     91

# %%
import pandas as pd
data=[
    ["Mandara",28,97],
    ["Varun",26,94],
    ["Pragna",23,91]
]
df = pd.DataFrame(data,columns=["name","age","marks"])
print(df)
# Out:
#       name  age  marks
# 0  Mandara   28     97
# 1    Varun   26     94
# 2   Pragna   23     91

# %%
import pandas as pd
data=[
    {"Name":"Mandara","Age":28,"Marks":97},
    {"Name":"Varun","Age":26,"Marks":94},
    {"Name":"Pragna","Age":23,"Marks":91}
]
df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Marks
# 0  Mandara   28     97
# 1    Varun   26     94
# 2   Pragna   23     91

# %%
import pandas as pd
s1=pd.Series([10,20,30],
index=["a","b","c"])
s2=pd.Series([40,50,60],
index=["a","b","c"])
df=pd.DataFrame({"Col1":s1,"Col2":s2})
print(df)
# Out:
#    Col1  Col2
# a    10    40
# b    20    50
# c    30    60

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8d3336b2-68a3-49dc-be1a-8599d657ba63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d3336b2-68a3-49dc-be1a-8599d657ba63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('data.csv.xls')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
import pandas as pd
df=pd.read_csv('data.csv.xls')
print(df)
print(type(df))
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
df=pd.read_csv('data.csv.xls')
print(df.to_string())
print(type(df.to_string()))
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-be1ca429-12eb-4b9a-b530-9d20dc1c2c76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-be1ca429-12eb-4b9a-b530-9d20dc1c2c76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('data.txt.xls')
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fff6dbb8-ef02-4e90-8f3b-530ac588b821" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fff6dbb8-ef02-4e90-8f3b-530ac588b821">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('data.csv.xls')
print(df)
print(type(df))
print(df.shape)
print(df.head())
print(df.tail())
print(df.describe())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
# <class 'pandas.core.frame.DataFrame'>
# (169, 4)
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# ...
