# %%
#creating a dictionary

thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year" : 2024
}
print(thisdict)
# Out:
# {'crop': 'rice', 'variety': 'IR-64', 'year': 2024}

# %%
thisdict={
    "crops":"cotton",
    "organic":True,
    "year":2024,
    "irrigation_methods":["drip","sprinkler","flood"]
}
print(thisdict)
# Out:
# {'crops': 'cotton', 'organic': True, 'year': 2024, 'irrigation_methods': ['drip', 'sprinkler', 'flood']}

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year" : 2024
}
print(type(thisdict))
# Out:
# <class 'dict'>

# %%
thisdict=dict(
    farmer_name="ramesh",
    age=45,
    village="mandya"
)
print(thisdict)
# Out:
# {'farmer_name': 'ramesh', 'age': 45, 'village': 'mandya'}

# %%
#accessing
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year" : 2024
}
x=thisdict["variety"]
print(x)
#get( method)
x=thisdict.get("variety")
print(x)
#get keys
x=thisdict.keys()
print(x)
#add new item
farm={
    "crop":"rice",
    "variety":"IR-64",
    "year":2022
}
x=farm.keys()
print(x)
farm["season"]="kharif"
print(x)
print(farm)
# Out:
# IR-64
# IR-64
# dict_keys(['crop', 'variety', 'year'])
# dict_keys(['crop', 'variety', 'year'])
# dict_keys(['crop', 'variety', 'year', 'season'])
# {'crop': 'rice', 'variety': 'IR-64', 'year': 2022, 'season': 'kharif'}

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year" : 2024
}
x=thisdict.values()
print(x)
#modify the value
farm={
    "crop":"rice",
    "variety":"IR-64",
    "year":2022
}
x=farm.values()
print(x)
farm["year"]=2026
print(x)
print(farm)
# Out:
# dict_values(['rice', 'IR-64', 2024])
# dict_values(['rice', 'IR-64', 2022])
# dict_values(['rice', 'IR-64', 2026])
# {'crop': 'rice', 'variety': 'IR-64', 'year': 2026}

# %%
x=thisdict.items()
print(x)
list2=list(thisdict.items())
print(list2)
tuple2=tuple(thisdict.items())
print(tuple2)
x_keys=tuple(thisdict.keys())
x_values=list(thisdict.values())
print(x_keys)
print(x_values)
#zip
pairs=zip(x_keys,x_values)
print(tuple(pairs))
pairs=zip(x_keys,x_values)
print(list(pairs))
# Out:
# dict_items([('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024)])
# [('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024)]
# (('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024))
# ('crop', 'variety', 'year')
# ['rice', 'IR-64', 2024]
# (('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024))
# [('crop', 'rice'), ('variety', 'IR-64'), ('year', 2024)]

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year" : 2024
}
if "variety" in thisdict:
  print("yes",'variety is one of the keys in the thisdict dictionary')
# Out:
# yes variety is one of the keys in the thisdict dictionary

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year" : 2024
}
if "irrigation" in thisdict:
  print("yes",'variety is one of the keys in the thisdict dictionary')
else:
  print("no")
# Out:
# no

# %%
#original dictionary
student={
    "name":"pragna",
    "roll_no":"AMB2172",
    "branch":"agriculture",
    "marks":88
}
print("original dictionary:",student)
#shallow copy
student_copy=student.copy()
print("copied dictionary:",student_copy)
#pop
removed_value=student.pop("marks")
print("removed value:",removed_value)
print("after pop():",student)
#pop item
last_item=student.popitem()
print("removed items:",last_item)
print("after popitem():",student)
#update
student.update({"year":4,"sem":8})
print("after update():",student)
#clear
student.clear()
print("after clear():",student)
# Out:
# original dictionary: {'name': 'pragna', 'roll_no': 'AMB2172', 'branch': 'agriculture', 'marks': 88}
# copied dictionary: {'name': 'pragna', 'roll_no': 'AMB2172', 'branch': 'agriculture', 'marks': 88}
# removed value: 88
# after pop(): {'name': 'pragna', 'roll_no': 'AMB2172', 'branch': 'agriculture'}
# removed items: ('branch', 'agriculture')
# after popitem(): {'name': 'pragna', 'roll_no': 'AMB2172'}
# after update(): {'name': 'pragna', 'roll_no': 'AMB2172', 'year': 4, 'sem': 8}
# after clear(): {}

# %%
#Assignment: NO new container

a = {"course": ["AI", "ML"]}
b = a
print(a is not b)
# Out:
# True

# %%
a = {"course": ["AI", "ML"]}
b = a.copy()
print(a is b)
print(a["course"] is not b["course"])
# Out:
# False
# False

# %%
a={"agri":["AI,ML"]}
b={"course":["HOT"]}
c=b.copy()
print(a is b)
print(b is c)
print(b is not c)
print(b["course"] is c["course"])
# Out:
# False
# False
# True
# True

# %%
squares={x:x*x for x in range(10)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
squares={x:x*x for x in range(2,10)}
print(squares)
# Out:
# {2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
squares={x:x+x for x in range(10)}
print(squares)
# Out:
# {0: 0, 1: 2, 2: 4, 3: 6, 4: 8, 5: 10, 6: 12, 7: 14, 8: 16, 9: 18}

# %%
#Nested Dictionaries

student = {
    "name": "Raj",
    "marks": {"math": 90, "cs": 95}
}
print(student)
# Out:
# {'name': 'Raj', 'marks': {'math': 90, 'cs': 95}}

# %%
student = {
    "name": "pragna",
    "marks": {"hot": 90, "pot": 95,"jack":90,"pack":89,"tat":88}
}
print(student)
# Out:
# {'name': 'pragna', 'marks': {'hot': 90, 'pot': 95, 'jack': 90, 'pack': 89, 'tat': 88}}

# %%
student = {
    "name": "pragna",
    "marks": {412: 90, 411: 95}
}
print(student)
print(student["marks"][412])
print(f"{student["name"]} {student["marks"]}")
# Out:
# {'name': 'pragna', 'marks': {412: 90, 411: 95}}
# 90
# pragna {412: 90, 411: 95}

# %%
#Iterating Properly Over Dictionaries
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year" : 2024
}
for key, value in thisdict.items():
    print(key,":", value)
# Out:
# crop : rice
# variety : IR-64
# year : 2024

# %%
thisdict={
    "crop":"turmeric",
    "variety":"CHNBT",
    "year" : 2025
}
for key, value in thisdict.items():
    print(key,":", value)
# Out:
# crop : turmeric
# variety : CHNBT
# year : 2025

# %%
thisdict={
    "crop":"rice",
    "variety":"IR-64",
    "year" : 2024
}
print(thisdict)
# Out:
# {'crop': 'rice', 'variety': 'IR-64', 'year': 2024}

# %%
thisdict={
    "crop":"turmeric",
    "variety":"CHNBT",
    "year" : 2025
}
x=thisdict.items()
print("crop",":", value)
print("variety",":", value)
print("year",":", value)
# Out:
# crop : 2025
# variety : 2025
# year : 2025

# %%
#Traditional way

crops = ["Rice", "Wheat", "Maize", "Cotton"]

i = 0
for crop in crops:
    print("Plot", i, ":", crop)
    i += 1
# Out:
# Plot 0 : Rice
# Plot 1 : Wheat
# Plot 2 : Maize
# Plot 3 : Cotton
