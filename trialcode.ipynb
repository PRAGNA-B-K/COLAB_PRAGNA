# %%
Crops_under_MSP=["Ragi","sugarcane","oilseeds"]
for crop in Crops_under_MSP:
  print(crop)
# Out:
# Ragi
# sugarcane
# oilseeds

# %%
days=input("Enter name of the day when sowing is done")  # "monday","tuesday","wednesday"
total_weight_of_seed_used=100
for day in range(1,7):
  print("number of seeds used:",total_weight_of_seed_used)
  print("number of days sowned")
# Out:
# Enter name of the day when sowing is done monday
# number of seeds used: 100
# number of days sowned
# number of seeds used: 100
# number of days sowned
# number of seeds used: 100
# number of days sowned
# number of seeds used: 100
# number of days sowned
# number of seeds used: 100
# number of days sowned
# number of seeds used: 100
# number of days sowned
