# %%
#no arguement is passed
def number_of_crops():
  return 150
number_of_crops()
# Out:
# 150

# %%
def weather_update():
  print("the weather today is sunny with no rain is excepted")
weather_update()
# Out:
# the weather today is sunny with no rain is excepted

# %%
def plant_info(plant_name):
  print(f"the {plant_name},requires atleast 8 hours of sunlight per day")
plant_info("snake tree")
# Out:
# the snake tree,requires atleast 8 hours of sunlight per day

# %%
def water_needs(plant_type):
  if plant_type=="corn":
    return 60
  elif plant_type=="wheat":
    return 40
  else:
    return 10
water_needs("wheat")
# Out:
# 40

# %%
def irrigation_needed(moisture_level,rainfall):
  if moisture_level<=79 and rainfall<=30:
    print("irrigation needed")
  else:
    print("irrigation not needed")
irrigation_needed(55,22)
# Out:
# irrigation needed

# %%
def total_yield(area,yield_per_hectare):
  return area*yield_per_hectare
total_yield(6,49)
# Out:
# 294

# %%
def total_yield():
  area=int(input("enter the area"))
  yield_per_hectare=int(input("enter the yield per hectare"))
  calculated_yield=area*yield_per_hectare
  return calculated_yield
y=total_yield()
print(y)
print("hi there")
# Out:
# enter the area5
# enter the yield per hectare30
# 150
# hi there

# %%
def is_ready_for_harvest(days_since_planted,plant_type):
  if days_since_planted>=120 and plant_type=="rice":
    return True
  else:
    return False
plant_type=input("enter the plant type")
days_since_planted=int(input("enter the daus since planted"))
is_ready_for_harvest(days_since_planted,plant_type)
# Out:
# enter the plant typerice
# enter the daus since planted50
# False

# %%
def weather_conditions():
  temperature=30
  humidity=40
  return temperature,humidity
temp,hum=weather_conditions()
print(f"temperature:{temp}C,humidity:{hum}%")
# Out:
# temperature:30C,humidity:40%

# %%
def add(x,y):
  return x+y
def subtract(x,y):
  return x-y
def multiply(x,y):
  return x*y
def divide(x,y):
  if y==0:
    return "error! division by zero"
  else:
    return x/y
def get_input():
   try:
    x=float(input("enter the first number"))
    y=float(input("enter the second number"))
    return x,y
   except ValueError:
    print("invalid input!please enter valid number")
    return get_input()
def print_menu():
   print("\n select operations:")
   print("1.Add")
   print("2.Subtract")
   print("3.Multiply")
   print("4.Divide")
   print("5.Exit")
def calculator():
  while True:
   print_menu()
   choice=input("enter choice(1/2/3/4/5):")
   if choice=='5':
    print("exiting the calculator")
    break
   x,y=get_input()
   if choice=='1':
    print(f"{x}+{y}={add(x,y)}")
   elif choice=='2':
    print(f"{x}-{y}={subtract(x,y)}")
   elif choice=='3':
    print(f"{x}*{y}={multiply(x,y)}")
   elif choice=='4':
    print(f"{x}/{y}={divide(x,y)}")
   else:
    print("invalid input! please select a valid operation(1/2/3/4/5)")
calculator()
9print("done with program")
# Out:
#  select operations:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 5.Exit
# enter choice(1/2/3/4/5):1
# enter the first number40
# enter the second number60
# 40.0+60.0=100.0
#
#  select operations:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 5.Exit
# enter choice(1/2/3/4/5):2
# enter the first number40
# enter the second number14
# 40.0-14.0=26.0
#
#  select operations:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 5.Exit
# enter choice(1/2/3/4/5):3
# enter the first number6
# enter the second number
# invalid input!please enter valid number
# enter the first number90
# enter the second number9
# 90.0*9.0=810.0
#
#  select operations:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 5.Exit
# enter choice(1/2/3/4/5):4
# enter the first number60
# enter the second number6
# 60.0/6.0=10.0
#
#  select operations:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 5.Exit
# enter choice(1/2/3/4/5):5
# exiting the calculator
# done with program
