# %%
#Crop Suitability Check
soil_moisture=float(input("Enter soil moisture: "))
rainfall=float(input("Enter Rainfall:"))
if soil_moisture>=70 and rainfall>=200:
  print("Suitable for rice")
else:
  print("Not suitable for rice")
# Out:
# Enter soil moisture: 100
# Enter Rainfall:100
# Not suitable for rice

# %%
#Crop yield classification
crop_yield=int(input("enter the yield(in quintals):"))
if crop_yield>=50:
  print("High yield")
elif crop_yield>=30:
  print("medium yield")
else:
  print("Low yield")
# Out:
#   File "/tmp/ipython-input-3943012145.py", line 2
#     yield=int(input("enter the yield(in quintals):"))
#     ^
# SyntaxError: assignment to yield expression not possible

# %%
#Crop yield classification
crop_yield=int(input("enter the yield(in quintals):"))
if crop_yield>=50:
  print("High yield")
elif crop_yield>=30:
  print("medium yield")
else:
  print("Low yield")
# Out:
# enter the yield(in quintals):25
# Low yield

# %%
crops=["Rice","Wheat","Maize","Millets"]
for crop in crops:
  print(crop)
# Out:
# Rice
# Wheat
# Maize
# Millets

# %%
#fertilizer recommendation system
soil_nitrogen_level=float(input("Enter soil nitrogen level(kg/ha):"))
crop=input("Enter the crop name(rice,wheat,maize):")
if crop=="rice" and soil_nitrogen_level<50:
  print("Apply urea")
elif crop=="wheat" and soil_nitrogen_level<40:
  print("Apply DAP")
else:
  print("Fertilizer not required")
# Out:
# Enter soil nitrogen level(kg/ha):30
# Enter the crop name(rice,wheat,maize):maize
# Fertilizer not required

# %%
#Crop availability check
crop_name=(input("Enter Crop name:"))
crops=["Rice","Wheat","Maize"]
if crop_name in crops:
  print("Crop available")
else:
  print("Crop not available")
# Out:
# Enter Crop name:Rice
# Crop available

# %%
germination_percentage=int(input("Enter germination percentage:"))
moisture_content=int(input("Enter moisture conten:"))
if germination_percentage>=85 and moisture_content<=12:
  print("high quality seed")
else:
  print("Low germination")
# Out:
# Enter germination percentage:85
# Enter moisture conten:12
# high quality seed

# %%
#pest monitoring system
while True:
  pest_count=int(input("Enter Pest count:"))
  if pest_count==0:
     print("monitoring stopped")
     break
else:
  print(f"pest count recorded:{pest_count}")
# Out:
# Enter Pest count:2
# Enter Pest count:4
# Enter Pest count:0
# monitoring stopped

# %%
#Irrigation scheduling

for field in range(1,6):
  print(f"enter Irrigating field{field}:")
# Out:
# enter Irrigating field1:
# enter Irrigating field2:
# enter Irrigating field3:
# enter Irrigating field4:
# enter Irrigating field5:

# %%
# Crop Display System
crops=["rice","wheat","maize"]
for crop in crops:
  print(crop)
# Out:
# rice
# wheat
# maize

# %%
#crop availability check
crops=["rice","wheat","maize"]
crop=input("enter the name of crop:")
if crop in crops:
  print("crop available")
else:
 print("crop not available")
# Out:
# enter the name of crop:ragi
# crop not available

# %%
#Seed quality evaluation
germination_percentage=int(input("enter germination percentage:"))
moisture_content=int(input("enter moisture content:"))
if germination_percentage>=85:
  if (moisture_content>=12):
    print("high quality seed")
  else:
    print("Low germination")
else:
  print("Low germination")
# Out:
# enter germination percentage:20
# enter moisture content:30
# Low germination

# %%
#Harvest readiness monitoring
while True:
  crop_maturity_percentage=int(input("enter crop maturity percentage:"))
  if crop_maturity_percentage>=100:
    print("crop ready for harvest")
    break
# Out:
# enter crop maturity percentage:50
# enter crop maturity percentage:100
# crop ready for harvest
