# %%
#negative indexing
thislist=["apple","banana","cherry"]
print(thislist[-2])
# Out:
# banana

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
thislist=["latha","maithri","indhu","kusuma","nanditha","kruthi","pragna"]
print(thislist[4:8])
# Out:
# ['nanditha', 'kruthi', 'pragna']

# %%
thislist=["latha","maithri","indhu","kusuma","nanditha","kruthi","pragna"]
print(thislist[7:6])
# Out:
# []

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[:7])
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[:4])
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[5:])
# Out:
# ['melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[1:])
# Out:
# ['banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[:-5])
# Out:
# ['apple', 'banana']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[-3:])
# Out:
# ['kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[-6:])
# Out:
# ['banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[-8:])
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[-3:4])
# Out:
# []

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[-7:-5])
# Out:
# ['apple', 'banana']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[2:-4])
# Out:
# ['cherry']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
print(thislist[1:-4])
# Out:
# ['banana', 'cherry']

# %%
thislist=["apple","banana","cherry"]
thislist[1]="blackcurrant"
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist[5]="blackberry"
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'blackberry', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist[7]="blackberry"
print(thislist)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2362605075.py in <cell line: 0>()
#       1 thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
# ----> 2 thislist[7]="blackberry"
#       3 print(thislist)
#
# IndexError: list assignment index out of range

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist[4:6]="blackberry"
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'b', 'l', 'a', 'c', 'k', 'b', 'e', 'r', 'r', 'y', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist[0:4]="blackberry"
print(thislist)
# Out:
# ['b', 'l', 'a', 'c', 'k', 'b', 'e', 'r', 'r', 'y', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist[0:4]=["blackberry"]
print(thislist)
# Out:
# ['blackberry', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist[0:4]=["blackberry","grapes","blackcurrant","lychee","muskmelon","watermelon"]
print(thislist)
# Out:
# ['blackberry', 'grapes', 'blackcurrant', 'lychee', 'muskmelon', 'watermelon', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist[0:4]="blackberry","grapes","blackcurrant","lychee","muskmelon","watermelon"
print(thislist)
# Out:
# ['blackberry', 'grapes', 'blackcurrant', 'lychee', 'muskmelon', 'watermelon', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist[0:4]=["blackberry","grapes"]
print(thislist)
# Out:
# ['blackberry', 'grapes', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist[0:2]=["blackberry","grapes"]
print(thislist)
# Out:
# ['blackberry', 'grapes', 'cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist.insert(5,"blackberry")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'blackberry', 'melon', 'mango']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist.insert=(2,"blackberry","grapes")
print(thislist)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2910875731.py in <cell line: 0>()
#       1 thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
# ----> 2 thislist.insert=(2,"blackberry","grapes")
#       3 print(thislist)
#
# AttributeError: 'list' object attribute 'insert' is read-only

# %%
#append
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist.append("blackberry")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'blackberry']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist.append(0,"blackberry")
print(thislist)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3049362326.py in <cell line: 0>()
#       1 thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
# ----> 2 thislist.append(0,"blackberry")
#       3 print(thislist)
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist.append(0)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 0]

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist.append("    ")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', '    ']

# %%
thislist=["apple","banana","cherry","orange","kiwi","melon","mango"]
thislist.append("blackberry")
thislist.append("7")
thislist.append(" ")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango', 'blackberry', '7', ' ']

# %%
#extend list
thislist=["apple","ba"]
